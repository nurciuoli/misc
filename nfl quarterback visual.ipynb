# %%
import pandas as pd

df = pd.read_csv('nflpassingstats_10_7_24.csv')
df = df.iloc[:-5]
df
# Out:
#                 Player  Pass Yds  Yds/Att  Att  Cmp  Cmp %  TD  INT   Rate  \
# 0           Sam Howell      1349      7.1  191  131   68.6   6    6   86.0
# 1       Tua Tagovailoa      1306      9.6  136   97   71.3   9    3  114.4
# 2     Matthew Stafford      1229      7.4  166  103   62.0   3    5   78.1
# 3         Kirk Cousins      1214      7.7  157  108   68.8  11    4  104.4
# 4          C.J. Stroud      1212      8.0  151   94   62.2   6    0  100.6
# 5        Justin Fields      1143      7.5  152   94   61.8  11    5   95.4
# 6       Justin Herbert      1106      7.6  145  103   71.0   7    1  106.3
# 7           Josh Allen      1048      7.8  135  101   74.8   9    4  106.6
# 8           Jared Goff      1029      7.8  131   91   69.5   6    3   98.4
# 9          Brock Purdy      1019      9.1  112   81   72.3   5    0  115.1
# 10      Russell Wilson      1014      7.7  132   89   67.4   9    2  106.7
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from adjustText import adjust_text
sns.set_style("darkgrid")
fig,ax = plt.subplots(figsize =(15,15))

sns.scatterplot(data = df,y='Yds/Att',x='Rate')
texts = []
for line in range(0,df.shape[0]):
     texts.append(ax.text(df.Rate[line], df['Yds/Att'][line], df.Player[line]))

adjust_text(texts)

plt.title('NFL QB Passer Rating vs. Yards per Attempt This Year through 10/7/23')
plt.xlabel('Passer Rating')
plt.savefig('qb_passer_ratings.png')
plt.show()

# %%
fig,ax = plt.subplots(figsize =(15,15))

sns.scatterplot(data = df,y='SckY',x='Rate')
texts = []
for line in range(0,df.shape[0]):
     texts.append(ax.text(df.Rate[line], df['SckY'][line], df.Player[line]))

adjust_text(texts)

plt.title('NFL QB Passer Rating vs. Sack Yards through 10/7/23')
plt.xlabel('Passer Rating')
plt.show()
